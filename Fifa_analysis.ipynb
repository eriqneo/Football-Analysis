# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa = pd.read_csv('players_20.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
#print all the columns
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
#how many nationalities are represented by players
fifa['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
#10 nationalities reprensented by players
fifa['nationality'].value_counts()[0:10]
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
#extracting the name of the countries without the values
fifa['nationality'].value_counts()[0:10].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands'],
#       dtype='object')

# %%
# prompt: from above create me a bar chart of the first nationalties represented

fifa['nationality'].value_counts()[0:10].plot(kind='bar')
plt.title('Top 10 Nationalities')
plt.xlabel('Nationality')
plt.ylabel('Number of Players')
plt.show()

# %%
#get player salaries
player_salaries = fifa [['short_name', 'wage_eur']]

player_salaries.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
# prompt: Using dataframe player_salary: create a bar chart using list . hart to have short_name and wage_eur
player_salary.head(5).plot(x='short_name', y='wage_eur', kind='barh', color = 'r')
plt.figure(figsize = (8,5))
plt.show()

# %%
#Germany players within the dataset
fifa['nationality'] == 'Germany'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
#get germany data
Germany = fifa[fifa['nationality'] == 'Germany']
Germany.head(10)
# Out:
#      sofifa_id                                         player_url  \
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 61      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...
# 109     235790  https://sofifa.com/player/235790/kai-havertz/2...
#
#         short_name              long_name  age         dob  height_cm  \
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31        M. Neuer           Manuel Neuer   33  1986-03-27        193
# ...

# %%
# prompt: Using dataframe Germany: sort with height_cm head(10)

Germany.sort_values(by='height_cm', ascending= False).head(10)
# Out:
#        sofifa_id                                         player_url  \
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 13635     208776  https://sofifa.com/player/208776/florian-strit...
# 4449      158657  https://sofifa.com/player/158657/thomas-kessle...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 11147     235018  https://sofifa.com/player/235018/moritz-nicola...
# 16184     240218  https://sofifa.com/player/240218/alexander-wei...
#
#            short_name            long_name  age         dob  height_cm  \
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199
# 1217         M. Esser        Michael Esser   31  1987-11-22        198
# ...

# %%
Germany.sort_values(by='weight_kg', ascending= False).head(10)
# Out:
#        sofifa_id                                         player_url  \
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
# 13201     241388  https://sofifa.com/player/241388/dennis-smarsc...
# 165       213331  https://sofifa.com/player/213331/jonathan-tah/...
# 5107      216284  https://sofifa.com/player/216284/florian-balla...
# 2746      224251  https://sofifa.com/player/224251/robin-zentner...
# 7574      216377  https://sofifa.com/player/216377/stefan-kutsch...
#
#           short_name        long_name  age         dob  height_cm  weight_kg  \
# 13576   L. Watkowiak  Lukas Watkowiak   23  1996-03-06        197        103
# ...

# %%
Germany.sort_values(by='shooting', ascending= False).head(10)
# Out:
#      sofifa_id                                         player_url  short_name  \
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...     M. Reus
# 276     200610  https://sofifa.com/player/200610/kevin-volland...  K. Volland
# 70      189596  https://sofifa.com/player/189596/thomas-muller...   T. Müller
# 217     183574  https://sofifa.com/player/183574/max-kruse/20/...    M. Kruse
# 120     206113  https://sofifa.com/player/206113/serge-gnabry/...   S. Gnabry
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...     L. Sané
# 175     212188  https://sofifa.com/player/212188/timo-werner/2...   T. Werner
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...    T. Kroos
# 845     200318  https://sofifa.com/player/200318/mark-uth/20/1...      M. Uth
# 631     206511  https://sofifa.com/player/206511/maximilian-ar...   M. Arnold
#
#              long_name  age         dob  height_cm  weight_kg nationality  \
# ...

# %%
#Get germany highest paid player in descending order

Germany.sort_values(by='wage_eur', ascending= False).head(10)[['short_name', 'wage_eur']]
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000
# 37         M. Reus    170000
# 31        M. Neuer    155000
# 215     S. Khedira    135000
# 49      M. Hummels    130000
# 135        M. Özil    125000

# %%
#player shooting
player_shooting = fifa[['short_name', 'shooting']]

# %%
# prompt: sort values by 'shooting" in descending order

player_shooting.sort_values(by='shooting', ascending=False).head(10)
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0
# 19           L. Suárez      89.0
# 96      Z. Ibrahimović      88.0
# 37             M. Reus      88.0
# 100            G. Bale      87.0
# 20      R. Lewandowski      87.0

# %%
#player defending
player_defending = fifa[['short_name', 'defending', 'nationality', 'club']]

# %%
# prompt: sort values by 'defending' in descending order

player_defending.sort_values(by='defending', ascending=False).head(10)
# Out:
#          short_name  defending  nationality               club
# 16     G. Chiellini       90.0        Italy           Juventus
# 7       V. van Dijk       90.0  Netherlands          Liverpool
# 11     K. Koulibaly       89.0      Senegal             Napoli
# 35         D. Godín       89.0      Uruguay              Inter
# 49       M. Hummels       89.0      Germany  Borussia Dortmund
# 29            Piqué       88.0        Spain       FC Barcelona
# 50  T. Alderweireld       88.0      Belgium  Tottenham Hotspur
# 40       A. Laporte       88.0       France    Manchester City
# 47    J. Vertonghen       87.0      Belgium  Tottenham Hotspur
# 67       L. Bonucci       87.0        Italy           Juventus

# %%
# prompt: Using dataframe fifa: get by 'club' 'Real Madrid' and store it in variable real_madrid

real_madrid = fifa[fifa['club'] == 'Real Madrid']

# %%
# prompt: Using dataframe real_madrid: sort by 'wage_eur' ascending order

real_madrid.sort_values(by='wage_eur', ascending=True).head(10)
# Out:
#        sofifa_id                                         player_url  \
# 13116     247411  https://sofifa.com/player/247411/diego-altube-...
# 9922      245290  https://sofifa.com/player/245290/adrian-de-la-...
# 8777      245287  https://sofifa.com/player/245287/sergio-lopez-...
# 4757      237681  https://sofifa.com/player/237681/takefusa-kubo...
# 8898      246608  https://sofifa.com/player/246608/alvaro-fidalg...
# 5676      244523  https://sofifa.com/player/244523/javier-hernan...
# 1256      243812  https://sofifa.com/player/243812/rodrygo-silva...
# 2652      231410  https://sofifa.com/player/231410/brahim-diaz/2...
# 568       238794  https://sofifa.com/player/238794/vinicius-jose...
# 1009      239053  https://sofifa.com/player/239053/federico-valv...
#
#            short_name                         long_name  age         dob  \
# 13116          Altube               Diego Altube Suárez   19  2000-02-22
# ...

# %%
# prompt: Using dataframe real_madrid: get 'nationality'

real_madrid['nationality'].value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Croatia                1
# Germany                1
# Costa Rica             1
# Wales                  1
# Colombia               1
# Serbia                 1
# Dominican Republic     1
# Uruguay                1
# Japan                  1
# Name: nationality, dtype: int64
